# %%
#example of pytorch example workflow
import torch
from torch import nn
import matplotlib.pyplot as plt

# %%
#1 Data (preparing and loading)
#use linear regression formula to make a straight line with known parameters
weight=0.7
bias=0.3

start=0
end=1
step=0.02
X =torch.arange(start,end,step).unsqueeze(dim=1)
y=weight * X + bias

X[:10] ,y[:10], len(X), len(y)
# Out:
# (tensor([[0.0000],
#          [0.0200],
#          [0.0400],
#          [0.0600],
#          [0.0800],
#          [0.1000],
#          [0.1200],
#          [0.1400],
#          [0.1600],
#          [0.1800]]),
#  tensor([[0.3000],
#          [0.3140],
#          [0.3280],
#          [0.3420],
#          [0.3560],
#          [0.3700],
#          [0.3840],
#          [0.3980],
#          [0.4120],
#          [0.4260]]),
#  50,
#  50)

# %%
## splitting to train and test set
train_split=int(0.8*len(X))
X_train,y_train=X[:train_split],y[:train_split]
X_test,y_test=X[train_split:],y[train_split:]

# %%
#visualization
def plot_prediction(train_data=X_train,
                    train_label=y_train,
                    test_data=X_test,
                    tests_labels=y_test,
                    predictions=None):
  #plots test and train data and compare prediction
  plt.figure(figsize=(10,7))
  plt.scatter(train_data,train_label,c="b", s=4,label="training data")

  plt.scatter(test_data,test_labels,c="g",s=4,label="testing data")

  if predictions is not None:
    plt.scatter(test_data, predictions,c="r",s=4 ,label="predictions")
  plt.legend(prop={"size":14});

# %%
plot_prediction();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10101/2923412519.py in <cell line: 0>()
# ----> 1 plot_prediction();
#
# /tmp/ipykernel_10101/3976309110.py in plot_prediction(train_data, train_label, test_data, tests_labels, predictions)
#       9   plt.scatter(train_data,train_label,c="b", s=4,label="training data")
#      10
# ---> 11   plt.scatter(test_data,test_labels,c="g",s=4,label="testing data")
#      12
#      13   if predictions is not None:
#
# NameError: name 'test_labels' is not defined
